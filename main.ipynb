# %%
print('Hello world')
# Out:
# Hello world

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame(np.random.randn(100, 2), columns=['A', 'B'])
plt.plot(data)
plt.show()
